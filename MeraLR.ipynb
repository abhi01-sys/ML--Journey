# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi01-sys/ML--Journey/blob/main/MeraLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class MeraLR():

  def __init__(self):
    self.m = None
    self.b = None

  def fit(self, X_train , Y_train):

    num = 0
    den = 0

    for i in range(X_train.shape[0]):

      num = num + ((X_train[i] - X_train.mean())*(Y_train[i] - Y_train.mean()))
      den = den + (X_train[i] - X_train.mean())*(X_train[i] - X_train.mean())

    self.m = num/den
    self.b = Y_train.mean() - (self.m * X_train.mean())
    print(self.m)
    print(self.b)

  def predict(self, X_test):

    return self.m * X_test + self.b

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
X = df.iloc[:,0:1].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_test
# Out:
# array([[8.58],
#        [7.15],
#        [5.88],
#        [6.22],
#        [4.57],
#        [4.79],
#        [5.32],
#        [6.86],
#        [8.35],
#        [6.87],
#        [8.94],
#        [7.9 ],
#        [6.93],
#        [5.91],
#        [7.32],
#        [7.82],
#        [5.09],
#        [7.42],
#        [6.94],
#        [7.73],
#        [6.19],
#        [7.28],
#        [6.73],
#        [7.2 ],
#        [8.21],
#        [6.75],
#        [7.87],
#        [7.6 ],
#        [8.63],
#        [5.12],
#        [8.15],
#        [7.36],
#        [8.31],
#        [6.6 ],
#        [6.59],
#        [7.47],
#        [7.93],
#        [6.29],
#        [6.37],
#        [6.47]])

# %%
lr = MeraLR()

# %%
lr.fit(X_train,y_train)
# Out:
# [0.55795197]
# [-0.89611192]

# %%
lr.predict(X_test[0])
# Out:
# array([3.89111601])
